# %%
print("Hello World")

# %%
import json

# %%
try:
    print("Hello World")
    status = "SUCCESS"
    print(1/0)
    message = {
        "status": status,
        "message": "operation completed"
    }
    dbutils.notebook.exit(json.dumps(message))
except Exception as e:
    print("Error")
    status = "ERROR"
    message = {
        "status": status,
        "message": str(e)
    }
    print(message)
    dbutils.notebook.exit(json.dumps(message))
