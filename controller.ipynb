# %%
try:
    result = dbutils.notebook.run("test1", 60)
    if result["status"] == "SUCCESS":
        status = result[status]
        message = f"""Child Notebook executed successfully. 
            
        """
